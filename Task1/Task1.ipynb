# %% [markdown]
# Author - Ashish Verma
#
# Task 1 - Stock Market Prediction

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
training_data = pd.read_csv('https://github.com/ashishverma5218/Bharat-Intern-Projects/blob/main/Task1/Google_Stock_Price_Train.csv?raw=true')

training_data.shape
training_data.head()
# Out:
#        Date    Open    High     Low   Close      Volume
# 0  1/3/2012  325.25  332.83  324.97  663.59   7,380,500
# 1  1/4/2012  331.27  333.87  329.08  666.45   5,749,400
# 2  1/5/2012  329.83  330.75  326.89  657.21   6,590,300
# 3  1/6/2012  328.34  328.77  323.68  648.24   5,405,900
# 4  1/9/2012  322.04  322.29  309.46  620.76  11,688,800

# %%
training_data = training_data.iloc[:, 1:2]

training_data.shape
training_data.head()
# Out:
#      Open
# 0  325.25
# 1  331.27
# 2  329.83
# 3  328.34
# 4  322.04

# %%
# feature scaling

from sklearn.preprocessing import MinMaxScaler

mm = MinMaxScaler(feature_range = (0, 1))
training_data = mm.fit_transform(training_data)

# %%
# Getting the inputs and outputs

x_train = training_data[0:1257]
y_train = training_data[1:1258]

print(x_train.shape)
print(y_train.shape)
# Out:
# (1257, 1)
# (1257, 1)

# %%
# reshaping

x_train = np.reshape(x_train, (1257, 1, 1))

print(x_train.shape)
# Out:
# (1257, 1, 1)

# %%
# importing the keras libraries and packages

import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# %%
# initializing the model
model = Sequential()

# adding the input layer and the LSTM layer
model.add(LSTM(units = 4, activation = 'sigmoid', input_shape = (None, 1)))

# adding the output layer
model.add(Dense(units = 1))

# compiling the model
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# fitting the RNN to the training data
model.fit(x_train, y_train, batch_size = 32, epochs = 200)
# Out:
# Epoch 1/200
# 40/40 [==============================] - 3s 3ms/step - loss: 0.0686
# Epoch 2/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0645
# Epoch 3/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0619
# Epoch 4/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0593
# Epoch 5/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0566
# Epoch 6/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0539
# Epoch 7/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0511
# Epoch 8/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0484
# Epoch 9/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0456
# Epoch 10/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0428
# Epoch 11/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0402
# Epoch 12/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0374
# Epoch 13/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0347
# Epoch 14/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0320
# Epoch 15/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0293
# Epoch 16/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0268
# Epoch 17/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0243
# Epoch 18/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0219
# Epoch 19/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0196
# Epoch 20/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0175
# Epoch 21/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0155
# Epoch 22/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0136
# Epoch 23/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0118
# Epoch 24/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0102
# Epoch 25/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0088
# Epoch 26/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0075
# Epoch 27/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0063
# Epoch 28/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0053
# Epoch 29/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0044
# Epoch 30/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0036
# Epoch 31/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0030
# Epoch 32/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0024
# Epoch 33/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0020
# Epoch 34/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0016
# Epoch 35/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 36/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 37/200
# 40/40 [==============================] - 0s 3ms/step - loss: 8.5112e-04
# Epoch 38/200
# 40/40 [==============================] - 0s 3ms/step - loss: 7.0255e-04
# Epoch 39/200
# 40/40 [==============================] - 0s 3ms/step - loss: 5.8488e-04
# Epoch 40/200
# 40/40 [==============================] - 0s 3ms/step - loss: 4.9709e-04
# Epoch 41/200
# 40/40 [==============================] - 0s 3ms/step - loss: 4.3167e-04
# Epoch 42/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.8205e-04
# Epoch 43/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.4709e-04
# Epoch 44/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.2078e-04
# Epoch 45/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.0208e-04
# Epoch 46/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.8813e-04
# Epoch 47/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7881e-04
# Epoch 48/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7164e-04
# Epoch 49/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6723e-04
# Epoch 50/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6470e-04
# Epoch 51/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.6225e-04
# Epoch 52/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.6114e-04
# Epoch 53/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.5983e-04
# Epoch 54/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.5880e-04
# Epoch 55/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.5908e-04
# Epoch 56/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.5909e-04
# Epoch 57/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.5764e-04
# Epoch 58/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.5757e-04
# Epoch 59/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.5708e-04
# Epoch 60/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.5839e-04
# Epoch 61/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.5776e-04
# Epoch 62/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.5802e-04
# Epoch 63/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.5749e-04
# Epoch 64/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.5707e-04
# Epoch 65/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.
200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.5528e-04
# Epoch 159/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.5191e-04
# Epoch 160/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.5183e-04
# Epoch 161/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.5566e-04
# Epoch 162/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.5032e-04
# Epoch 163/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.5284e-04
# Epoch 164/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.5510e-04
# Epoch 165/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.5705e-04
# Epoch 166/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.5345e-04
# Epoch 167/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.5210e-04
# Epoch 168/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5596e-04
# Epoch 169/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5950e-04
# Epoch 170/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5121e-04
# Epoch 171/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5657e-04
# Epoch 172/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5110e-04
# Epoch 173/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5117e-04
# Epoch 174/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5320e-04
# Epoch 175/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5410e-04
# Epoch 176/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5021e-04
# Epoch 177/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5633e-04
# Epoch 178/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5207e-04
# Epoch 179/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5471e-04
# Epoch 180/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5044e-04
# Epoch 181/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5383e-04
# Epoch 182/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5756e-04
# Epoch 183/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5354e-04
# Epoch 184/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5288e-04
# Epoch 185/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5092e-04
# Epoch 186/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5162e-04
# Epoch 187/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5178e-04
# Epoch 188/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5125e-04
# Epoch 189/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5223e-04
# Epoch 190/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5046e-04
# Epoch 191/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5401e-04
# Epoch 192/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5088e-04
# Epoch 193/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5540e-04
# Epoch 194/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5738e-04
# Epoch 195/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5142e-04
# Epoch 196/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5224e-04
# Epoch 197/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5250e-04
# Epoch 198/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5130e-04
# Epoch 199/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6061e-04
# Epoch 200/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5586e-04

# %%
# getting the real stock of 2017 i.e., importing the test dataset

test_data = pd.read_csv('https://github.com/ashishverma5218/Bharat-Intern-Projects/blob/main/Task1/Google_Stock_Price_Test.csv?raw=true')
real_stock_price = test_data.iloc[:,1:2]
real_stock_price.head()
# Out:
#      Open
# 0  778.81
# 1  788.36
# 2  786.08
# 3  795.26
# 4  806.40

# %%
# getting the predicted stock price of 2017

inputs = real_stock_price
inputs = mm.transform(inputs)
inputs = np.reshape(inputs, (20, 1, 1))



predicted_stock_price = model.predict(inputs)
predicted_stock_price = mm.inverse_transform(predicted_stock_price)
# Out:
# 1/1 [==============================] - 0s 25ms/step

# %%
predicted_stock_price
# Out:
# array([[776.70105],
#        [785.4475 ],
#        [783.3656 ],
#        [791.7239 ],
#        [801.77924],
#        [803.08984],
#        [800.5209 ],
#        [802.4437 ],
#        [802.7489 ],
#        [802.3899 ],
#        [801.24915],
#        [800.6288 ],
#        [802.2372 ],
#        [802.5424 ],
#        [815.9603 ],
#        [822.42   ],
#        [829.5947 ],
#        [826.88556],
#        [809.1717 ],
#        [793.174  ]], dtype=float32)

# %%
# visualizing the results

plt.plot(real_stock_price, color = 'red', label = 'Real Google Stock Price')
plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted Google Stock Price')
plt.title('Stock Prediction')
plt.xlabel('Time')
plt.ylabel('Google Stock Price')
plt.legend()
plt.show()

# %%
# getting the real stock price of 2012 - 2016

training_data = pd.read_csv('https://github.com/ashishverma5218/Bharat-Intern-Projects/blob/main/Task1/Google_Stock_Price_Train.csv?raw=true')

training_data.shape
training_data.head()
# Out:
#        Date    Open    High     Low   Close      Volume
# 0  1/3/2012  325.25  332.83  324.97  663.59   7,380,500
# 1  1/4/2012  331.27  333.87  329.08  666.45   5,749,400
# 2  1/5/2012  329.83  330.75  326.89  657.21   6,590,300
# 3  1/6/2012  328.34  328.77  323.68  648.24   5,405,900
# 4  1/9/2012  322.04  322.29  309.46  620.76  11,688,800

# %%
training_data = training_data.iloc[:, 1:2]

training_data.shape
training_data.head()
# Out:
#      Open
# 0  325.25
# 1  331.27
# 2  329.83
# 3  328.34
# 4  322.04

# %%
# getting the predicted stock price of 2012-2016

predicted_stock_price = model.predict(x_train)
predicted_stock_price = mm.inverse_transform(predicted_stock_price)

# %%
# visualizing the whole training data results

plt.plot(training_data, color = 'red', label = 'Real Google Stock Price')
plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted Google Stock Price')
plt.title('Stock Prediction')
plt.xlabel('Time')
plt.ylabel('Google Stock Price')
plt.legend()
plt.show()

# %%
# Evaluating the RNN model

import math

from sklearn.metrics import mean_squared_error

rmse = math.sqrt(mean_squared_error(real_stock_price, predicted_stock_price))

print(rmse)
# Out:
# 5.063731322951662
